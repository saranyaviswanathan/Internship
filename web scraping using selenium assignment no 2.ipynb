# %% [markdown]
# # WEB SCRAPING – ASSIGNMENT 2

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\ADMIN\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")  

designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div[1]/input")

location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")

search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

#scraping job title from the given page

title_tags=driver.find_elements(By.XPATH,'//a [@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
    
#scraping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
    
#scraping company name from the given web page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping  job experience from the given web page
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'JOB_title':job_title,'Job_location':job_location,'Company_name':company_name,"Exp_required":experience_required})
df
# Out:
#                                            JOB_title  \
# 0                      BYJU'S DBEL : Sr Data Analyst
# 1                              Business Data Analyst
# 2  Sr. Analyst Manufacturing Data Analytics/ Data...
# 3                           Clinical Data Analyst II
# 4                           Finance Tax Data Analyst
# 5                               Data Analyst French)
# 6                            Business Data Analyst 3
# 7                            Business Data Analyst 3
# 8                            Business Data Analyst 1
# 9         Business & Data Analyst- Assistant Manager
#
#                                   Job_location  \
# 0                          Bangalore/Bengaluru
# 1                          Bangalore/Bengaluru
# 2                          Bangalore/Bengaluru
# 3                          Bangalore/Bengaluru
# 4                          Bangalore/Bengaluru
# 5          Bangalore/Bengaluru, Pune, Vadodara
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome(r"C:\Users\ADMIN\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")  

designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div[1]/input")

location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")

search.click()

# %%
job_title=[]
job_location=[]
company_name=[]

#scraping job title from the given page

title_tags=driver.find_elements(By.XPATH,'//a [@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
    
#scraping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
    
#scraping company name from the given web page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
print(len(job_title),len(job_location),len(company_name))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'JOB_title':job_title,'Job_location':job_location,'Company_name':company_name,"Exp_required":experience_required})
df
# Out:
#                                            JOB_title  \
# 0                   Analystics & Modeling Specialist
# 1  Job||Job Opening For AI Technologist - Data Sc...
# 2  Hiring For DATA Scientist @ NTT DATA Business ...
# 3                                  Lead ML Scientist
# 4   Senior Manager - EmTech - Machine Learning - P&T
# 5  Urgent Job Opening For AI Practitioner - Data ...
# 6                   Assistant Manager - Data Science
# 7             Data Scientist / Senior Data Scientist
# 8                      Tcs Hiring For Data Scientist
# 9                                     Data Scientist
#
#                                         Job_location  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 1  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...
# 2  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...
# 3                        Bangalore/Bengaluru, Mumbai
# 4  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...
# 5  Bangalore/Bengaluru, Kochi/Cochin, New Delhi, ...
# ...

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the search button.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results you get.
# 6. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome(r"C:\Users\ADMIN\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")  
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")

search.click()

# %%
location=driver.find_element(By.XPATH,"//span[@title='Delhi / NCR']")
                                                 
location.click()

# %%
salary=driver.find_element(By.XPATH,"//span[@title='3-6 Lakhs']")

salary.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

#scraping job title from the given page

title_tags=driver.find_elements(By.XPATH,'//a [@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
    
#scraping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
    
#scraping company name from the given web page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping  job experience from the given web page
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'JOB_title':job_title,'Job_location':job_location,'Company_name':company_name,"Exp_required":experience_required})
df
# Out:
#                                            JOB_title  \
# 0  Job||Job Opening For AI Technologist - Data Sc...
# 1                   Data Scientist - Noida/Bangalore
# 2                    DigitalBCG GAMMA Data Scientist
# 3                                Lead Data Scientist
# 4                                     Data Scientist
# 5              Data Scientist - Predictive Analytics
# 6                Chat-bot Developer / Data Scientist
# 7                Data Scientist / Chat-bot Developer
# 8                                     Data Scientist
# 9                  Data Scientist - Engine Algorithm
#
#                                         Job_location             Company_name  \
# 0  New Delhi, Hyderabad/Secunderabad, Pune, Chenn...                    Wipro
# 1                         Noida, Bangalore/Bengaluru                      EXL
# 2                     New Delhi, Bangalore/Bengaluru  Boston Consulting Group
# ...

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price
#
#
# The attributes which you have to scrape is ticked marked in the below image.
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url : https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and
# click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the
# required data as usual.
# ASSIGNMENT 2
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then
# click on it.
# 5. Now scrape data from this page as usual
# 6. Repeat this until you get data for 100 sunglasses.

# %%
driver=webdriver.Chrome(r"C:\Users\ADMIN\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")  

product.send_keys('sunglasses')

# %%
search_btn=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search_btn.submit()

# %%
brand_name=[]
product_description=[]
buy_price=[]

brand_tags=driver.find_elements(By.CLASS_NAME,'_2WkVRV')
for i in brand_tags[:100]:
    brand=i.text
    brand_name.append(brand)
    
    
product_tags=driver.find_elements(By.CLASS_NAME,'IRpwTa')
for i in product_tags[:100]:
    product=i.text
    product_description.append(product)
    
    
price_tags=driver.find_elements(By.CLASS_NAME,'_3bPFwb')
for i in price_tags[:100]:
    price=i.text
    buy_price.append(price)

# %%
#to fetch the url

url=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
url[0:3]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="44627d74a20a435e2e3790dfe40f5f87", element="6b1ecccd-a3fd-4f2f-be9d-883cdb3d3a6e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="44627d74a20a435e2e3790dfe40f5f87", element="4597df03-a87e-4d1a-ba69-cf23a1abb3d1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="44627d74a20a435e2e3790dfe40f5f87", element="02d05bfd-f328-4b10-8423-66abfac938ec")>]

# %%
for i in url[0:3]:
    print(i.get_attribute('href'))
# Out:
# https://www.flipkart.com/vincent-chase-lenskart-retro-square-sunglasses/p/itmb5f58c7d01e82?pid=SGLGFYDUHNXNHUFC&lid=LSTSGLGFYDUHNXNHUFCYMSZKQ&marketplace=FLIPKART&q=sunglasses&store=26x&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=en_OWhqd9jUidg0N82zlgJPP%2FX8u%2BxSwQ8AUbX7Fd2RUsH7GuKMIdB8uQTOrMER%2Bc44sX1NnEzofunIrpUb38frmA%3D%3D&ppt=hp&ppn=homepage&ssid=e76raoe3bk0000001661445516598&qH=2cc465e3eef5bff0
# https://www.flipkart.com/vincent-chase-round-sunglasses/p/itm660d3371266b4?pid=SGLG8D97VVNMB4HK&lid=LSTSGLG8D97VVNMB4HKPEULBS&marketplace=FLIPKART&q=sunglasses&store=26x&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=en_OWhqd9jUidg0N82zlgJPP%2FX8u%2BxSwQ8AUbX7Fd2RUsE3jcxV%2BTDt1THhHe%2B7xqi5gX%2FJdn%2BmIjDzd5mD%2FXq%2F9Q%3D%3D&ppt=hp&ppn=homepage&ssid=e76raoe3bk0000001661445516598&qH=2cc465e3eef5bff0
# ...

# %%
product_description=[]
brand_name=[]
buy_price=[]

start=0
end=3

for page in range(start,end):
    product_tags=driver.find_elements(By.CLASS_NAME,'IRpwTa')
    for i in product_tags:
        if len(product_description) < 100:
            product=i.text
            product_description.append(product)
         
            
    brand_tags=driver.find_elements(By.CLASS_NAME,'_2WkVRV')
    for i in brand_tags:
        if len(brand_name) < 100:
            brand=i.text
            brand_name.append(brand)

    price_tags=driver.find_elements(By.CLASS_NAME,'_3bPFwb')
    for i in price_tags:
        if len(buy_price) < 100:
            price=i.text
            buy_price.append(price)
    
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]//span')
    next_button.click()
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15520/3010052216.py in <module>
#      27
#      28     next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]//span')
# ---> 29     next_button.click()
#      30     time.sleep(3)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      86     def click(self) -> None:
#      87         """Clicks the element."""
# ---> 88         self._execute(Command.CLICK_ELEMENT)
#      89
#      90     def submit(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     394             params = {}
#     395         params['id'] = self._id
# --> 396         return self._parent.execute(command, params)
#     397
# ...

# %%
print(len(brand_name),len(product_description),len(buy_price))
# Out:
# 40 40 40

# %%
df=pd.DataFrame({'brand name':brand_name,'product':product_description,'price':buy_price})
df
# Out:
#            brand name                                            product  \
# 0       VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...
# 1       VINCENT CHASE     Polarized, UV Protection Round Sunglasses (51)
# 2           New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 3            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 4           New Specs          UV Protection Oval Sunglasses (Free Size)
# 5           Elligator                UV Protection Round Sunglasses (54)
# 6              PIRASO          UV Protection Rectangular Sunglasses (52)
# 7       VINCENT CHASE     Polarized, UV Protection Round Sunglasses (51)
# 8              PIRASO              UV Protection Aviator Sunglasses (58)
# 9          PHENOMENAL         UV Protection Retro Square Sunglasses (53)
# 10             PIRASO              UV Protection Aviator Sunglasses (54)
# 11      VINCENT CHASE  by Lenskart Polarized, UV Protection Aviator S...
# ...

# %% [markdown]
# #NOTE- i was able to get the output for 100 sunglasses initially and due to element click interception error which happens because of dynamic website (as said in the webinar)..I was able to get output for first 40 sunglasses

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone.
# This task will be done in following steps:
# 1. First get the webpage https://www.flipkart.com/
# 2. Enter “iphone 11” in “Search” field .
# 3. Then click the search button.
# As shown in the above page you have to scrape the tick marked attributes.These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100 reviews

# %%
driver=webdriver.Chrome(r"C:\Users\ADMIN\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")  

product.send_keys('iphone 11')

# %%
search_btn=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search_btn.submit()

# %%
url=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
driver.get(url[0].get_attribute('href'))

# %%
rating_score=[]
review_summary=[]
full_review=[]

rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[:100]:
    rating=i.text
    rating_score.append(rating)
    
    
review_tags=driver.find_elements(By.CLASS_NAME,'_2-N8zT')
for i in review_tags[:100]:
    review=i.text
    review_summary.append(review)
    
    
full_tags=driver.find_elements(By.CLASS_NAME,'t-ZTKy')
for i in full_tags[:100]:
    full=i.text
    full_review.append(full)

# %%
url_all_reviews=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[6]/div/a')
driver.get(url_all_reviews[0].get_attribute('href'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15520/386480503.py in <module>
#       1 url_all_reviews=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[6]/div/a')
# ----> 2 driver.get(url_all_reviews[0].get_attribute('href'))
#
# IndexError: list index out of range

# %%
rating_score=[]
review_summary=[]
full_review=[]

start=0
end=11

for page in range(start,end):
    rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    rating_tags
    for i in rating_tags:
        if len(rating_score) < 100:
            rating=i.text
            rating_score.append(rating)
     
            
    review_tags=driver.find_elements(By.CLASS_NAME,'_2-N8zT')
    for i in review_tags:
        if len(review_summary) < 100:
            review=i.text
            review_summary.append(review)

    full_tags=driver.find_elements(By.CLASS_NAME,'t-ZTKy')
    for i in full_tags:
        if len(full_review) < 100:
            full=i.text
            full_review.append(full)
            
    url_next=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')
    if len(url_next) == 1:
        for i in url_next[:1]:
            driver.get(i.get_attribute('href'))
    for i in url_next[1:2]:
        driver.get(i.get_attribute('href'))
   
    time.sleep(3)

# %%
print(len(rating_score),len(review_summary),len(full_review))
# Out:
# 100 100 100

# %%
df=pd.DataFrame({'rating':rating_score,'summary':review_summary,'full review':full_review})
df
# Out:
#    rating              summary  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3
# 4
# ..    ...                  ...
# 95
# 96
# 97
# 98
# 99
#
#                                           full review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3
# 4
# ..                                                ...
# 95
# 96
# 97
# 98
# 99
#
# [100 rows x 3 columns]

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
# search field.
# You have to scrape 4 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price
# As shown in the below image, you have to scrape the tick marked attributes.

# %%
driver=webdriver.Chrome(r"C:\Users\ADMIN\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")  

product.send_keys('sneakers')

# %%
search_btn=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search_btn.submit()

# %%
brand_name=[]
product_description=[]
buy_price=[]
offer_percent=[]

brand_tags=driver.find_elements(By.CLASS_NAME,'_2WkVRV')
for i in brand_tags[:100]:
    brand=i.text
    brand_name.append(brand)
    
    
product_tags=driver.find_elements(By.CLASS_NAME,'IRpwTa')
for i in product_tags[:100]:
    product=i.text
    product_description.append(product)
    
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[:100]:
    price=i.text
    buy_price.append(price)
    
offer_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in offer_tags[:100]:
    offer=i.text
    offer_percent.append(offer)

# %%
url=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
url[0:3]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b5420c95e6b961245c19c853cba2b683", element="e8eae870-58b9-42b1-9dee-b137b1f0d3cf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5420c95e6b961245c19c853cba2b683", element="90c831af-6011-4eb9-8f1a-9826ed18018e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5420c95e6b961245c19c853cba2b683", element="95625697-6ed4-41a8-99e5-bf5d52a869cc")>]

# %%
for i in url[0:3]:
    print(i.get_attribute('href'))
# Out:
# https://www.flipkart.com/k-footlance-men-s-casual-sneaker-shoes-running-walking-sneakers-men/p/itmbe6800418195e?pid=SHOGHYRUUHDFHJNW&lid=LSTSHOGHYRUUHDFHJNWEFPLHR&marketplace=FLIPKART&q=sneakers&store=osp&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=en_gU35PAlchDPxYSgCT7nGWbKVeSL%2BDc%2B2WorqsWNVEybhWmCxcYwE5LsxNp%2FbgRcHJB%2B3llOU9%2FQtg1iX4wjWaw%3D%3D&ppt=hp&ppn=homepage&ssid=4ha3zpykw00000001661445706428&qH=a1743c0d39461290
# https://www.flipkart.com/chevit-stylish-comfortable-lightweight-breathable-t-blue-sneakers-men/p/itm5dada34a6488a?pid=SHOGFHRBGBBGD8RT&lid=LSTSHOGFHRBGBBGD8RT58FWOO&marketplace=FLIPKART&q=sneakers&store=osp&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=en_gU35PAlchDPxYSgCT7nGWbKVeSL%2BDc%2B2WorqsWNVEyZckTVr%2BflJkqVj29sop9KiSB97pmr062oYvDfSwgKCBg%3D%3D&ppt=hp&ppn=homepage&ssid=4ha3zpykw00000001661445706428&qH=a1743c0d39461290
# ...

# %%
product_description=[]
brand_name=[]
buy_price=[]
offer_percent=[]

start=0
end=3

for page in range(start,end):
    product_tags=driver.find_elements(By.CLASS_NAME,'IRpwTa')
    for i in product_tags:
        if len(product_description) < 100:
            product=i.text
            product_description.append(product)
         
            
    brand_tags=driver.find_elements(By.CLASS_NAME,'_2WkVRV')
    for i in brand_tags:
        if len(brand_name) < 100:
            brand=i.text
            brand_name.append(brand)

    price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags:
        if len(buy_price) < 100:
            price=i.text
            buy_price.append(price)
            
    offer_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in offer_tags:
        if len(offer_tags) < 100:
            offer=i.text
            offer_percent.append(offer)
    
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
        
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15520/2607642587.py in <module>
#      34
#      35     next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
# ---> 36     next_button.click()
#      37
#      38     time.sleep(3)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      86     def click(self) -> None:
#      87         """Clicks the element."""
# ---> 88         self._execute(Command.CLICK_ELEMENT)
#      89
#      90     def submit(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     394             params = {}
#     395         params['id'] = self._id
# --> 396         return self._parent.execute(command, params)
#     397
# ...

# %%
print(len(brand_name),len(product_description),len(buy_price),len(offer_percent))
# Out:
# 40 40 40 40

# %%
df=pd.DataFrame({'brand':brand_name,'product':product_description,'price':buy_price,'offer':offer_percent})
df
# Out:
#                   brand                                            product  \
# 0          K- FOOTLANCE  Men's Casual sneaker shoes running shoes walki...
# 1                Chevit  Stylish Comfortable Lightweight, Breathable T....
# 2              Magnolia                                   Sneakers For Men
# 3                Labbin                                   Sneakers For Men
# 4              Magnolia                                   Sneakers For Men
# 5              KWIK FIT  Kwik FIT casual sneaker shoes and partywear sh...
# 6                  aadi  Mesh | Ultralightweight | Comfortable | Breath...
# 7                 BIRDE          Premium Sneakers for men Sneakers For Men
# 8                Chevit  Super Stylish & Trendy Combo Pack of 02 Pairs ...
# 9                Chevit  Unique & Perfect Collection Combo Pack of 02 S...
# 10            Deals4you                                   Sneakers For Men
# ...

# %% [markdown]
# #NOTE- i was able to get the output for 100 sneakers initially and due to element click interception error
# which happens because of dynamic website (as said in the webinar)..I was able to get output for first 40 sneakers only

# %% [markdown]
# Q7: Go to the link - https://www.myntra.com/shoes
# Set second Price filter and Color filter to “Black”, as shown in the below image.
# And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe
# description, price of the shoe as shown in the below image.

# %%
driver=webdriver.Chrome(r"C:\Users\ADMIN\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.myntra.com/shoes")

# %% [markdown]
# This website can't be scraped

# %% [markdown]
# Q8: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” as shown in the below image:
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributesfor each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
driver=webdriver.Chrome(r"C:\Users\ADMIN\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.amazon.in/")

# %%
product=driver.find_element(By.XPATH,"//input[@type='text']")  

product.send_keys('Laptop')

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div')

search_btn.click()

# %%
CPU_type=driver.find_element(By.XPATH,'//span[text()="Intel Core i7"]')

CPU_type.click()

# %%
product_title=[]
product_ratings=[]
product_price=[]

title_tags=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in title_tags[0:10]:
    title=i.text
    product_title.append(title)
    
    
ratings_tags=driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]')
for i in ratings_tags[0:10]:
    ratings=i.text
    product_ratings.append(ratings)
    
price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in price_tags[0:10]:
    price=i.text
    product_price.append(price)

# %%
print(len(product_title),len(product_ratings),len(product_price))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'title':product_title,'ratings':product_ratings,'price':product_price})
df
# Out:
#                                                title ratings     price
# 0  Lenovo Ideapad Gaming 3 Intel Core i7 10th Gen...      24    69,990
# 1  ASUS Zenbook 14 OLED (2022), 14" (35.56 cms) 2...      16  1,04,990
# 2  Samsung Galaxy Book2 Intel 12th Gen core i7 39...      27    79,990
# 3  Dell New G15 5520 Gaming Laptop, Intel i7-1270...       4  1,28,239
# 4  Lenovo ThinkPad E14 Intel Core i7 11th Gen 14-...      71    94,990
# 5  Fujitsu UH-X 11th Gen Intel Core i7 13.3” FHD ...      24    84,990
# 6  Lenovo Ideapad Gaming 3 Intel Core i7 10th Gen...      32    69,990
# 7  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, I...      26    57,700
# 8  ASUS TUF Gaming F15 (2022), 15.6-inch (39.62 c...      19  1,04,990
# 9  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...      18    87,990

# %% [markdown]
# Q9: Write a python program to scrape data for first 10 job results for Data Scientist Designation in Noida
# location. You have to scrape company name, No. of days ago when job was posted, Rating of the company.
# This task will be done in following steps:
# 1. First get the webpage https://www.ambitionbox.com/
# 2. Click on the Job option as shown in the image
# 3.After reaching to the next webpage, In place of “Search by Designations, Companies, Skills” enter
# “Data Scientist” and click on search button.
# 4. You will reach to the following web page click on location and in place of “Search location” enter
# “Noida” and select location “Noida”.
# 5. Then scrape the data for the first 10 jobs results you get on the above shown page.
# 6. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome(r"C:\Users\ADMIN\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.ambitionbox.com/")

# %%
job_btn=driver.find_element(By.XPATH,'/html/body/div[1]/nav[2]/div/ul/li[5]/a')

job_btn.click()

# %%
designation=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/div/span/input")  

designation.send_keys('Data Scientist')

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/button')

search_btn.click()

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[1]/i")

location.click()

# %%
checkbox=driver.find_element(By.XPATH,"//input[@id='location_Noida']")

checkbox.click()

# %%
company_name=[]
days_posted=[]
company_rating=[]

name_tags=driver.find_elements(By.XPATH,'//p[@class="company body-medium"]')
for i in name_tags[0:10]:
    name=i.text
    company_name.append(name)
    
    
days_tags=driver.find_elements(By.XPATH,'//span[@class="body-small-l"]')
for i in days_tags[0:10]:
    days=i.text
    days_posted.append(days)
    
rating_tags=driver.find_elements(By.XPATH,'//span[@class="body-small"]')
for i in rating_tags[0:10]:
    rating=i.text
    company_rating.append(rating)

# %%
print(len(company_name),len(days_posted),len(rating_tags))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'company name':company_name,'no.of days':days_posted,'company rating':company_rating})
df
# Out:
#                                      company name       no.of days  \
# 0                         CBRE South Asia Pvt Ltd          14d ago
# 1                   GENPACT India Private Limited   via naukri.com
# 2                                         Genpact           7d ago
# 3        Ericsson India Global Services Pvt. Ltd.   via naukri.com
# 4                   GENPACT India Private Limited           9d ago
# 5  Optum Global Solutions (India) Private Limited  via iimjobs.com
# 6  Optum Global Solutions (India) Private Limited          24d ago
# 7        Ericsson India Global Services Pvt. Ltd.   via naukri.com
# 8                      SOPRA STERIA INDIA LIMITED          17d ago
# 9                    One97 Communications Limited   via naukri.com
#
#   company rating
# 0            4.3
# 1            4.0
# 2            4.0
# 3            4.3
# 4            4.0
# 5            4.1
# 6            4.1
# 7            4.3
# 8            4.2
# 9            3.7

# %% [markdown]
# Q10: Write a python program to scrape the salary data for Data Scientist designation.
# You have to scrape Company name, Number of salaries, Average salary, Minsalary, Max Salary.
# The above task will be, done as shown in the below steps:
# 1. First get the webpage https://www.ambitionbox.com/
# 2. Click on the salaries option as shown in the image.
# 3. After reaching to the following webpage, In place of “Search Job Profile” enters “Data Scientist” and
# then click on “Data Scientist”.
# You have to scrape the data ticked in the above image.
# 4. Scrape the data for the first 10 companies. Scrape the company name, total salary record, average
# salary, minimum salary, maximum salary, experience required.
# 5. Store the data in a dataframe.

# %%
driver=webdriver.Chrome(r"C:\Users\ADMIN\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.ambitionbox.com/")

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/nav[2]/div/ul/li[3]/i')

search_btn.click()

# %%
salary_btn=driver.find_element(By.XPATH,'/html/body/div[1]/nav[2]/div/ul/li[3]/div/ul/li[1]/div/div[2]/p')

salary_btn.click()

# %%
designation=driver.find_element(By.XPATH,"/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/input")  

designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.XPATH,'/html/body/div/div/div/main/section[1]/div[2]/div[1]/i[1]')

search.click()

# %%
company_name=[]
salary_record=[]
avg_salary=[]
min_salary=[]
max_salary=[]
experience_required=[]

name_tags=driver.find_elements(By.XPATH,'//div[@class="company-info"]//a')
for i in name_tags[0:10]:
    name=i.text
    company_name.append(name)
    
    
salary_tags=driver.find_elements(By.XPATH,'//span[@class="datapoints"]')
for i in salary_tags[0:10]:
    salary=i.text
    salary_record.append(salary)
    
avg_tags=driver.find_elements(By.XPATH,'//p[@class="averageCtc"]')
for i in avg_tags[0:10]:
    avg=i.text
    avg_salary.append(avg)
    
min_tags=driver.find_elements(By.XPATH,'//div[@class="value body-medium"]')
for i in min_tags[0:20:2]:
    min=i.text
    min_salary.append(min)
    
max_tags=driver.find_elements(By.XPATH,'//div[@class="value body-medium"]')
for i in max_tags[1:20:2]:
    max=i.text
    max_salary.append(max)
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class="sbold-list-header"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(company_name),len(salary_record),len(avg_salary),len(min_salary),len(max_salary),len(experience_required))
# Out:
# 10 10 10 10 10 10

# %%
df=pd.DataFrame({'company name':company_name,'no.of salary records':salary_record,'avg salary':avg_salary,'min salary':min_salary,'max salary':max_salary,'experience':experience_required})
df
# Out:
#                                         company name     no.of salary records  \
# 0                     Walmart\nData Scientist Salary   (based on 22 salaries)
# 1                    Ab Inbev\nData Scientist Salary   (based on 53 salaries)
# 2                       Optum\nData Scientist Salary   (based on 48 salaries)
# 3                          ZS\nData Scientist Salary   (based on 33 salaries)
# 4           Fractal Analytics\nData Scientist Salary  (based on 109 salaries)
# 5             Tiger Analytics\nData Scientist Salary   (based on 65 salaries)
# 6  Legato Health Technologies\nData Scientist Salary   (based on 11 salaries)
# 7                    Tredence\nData Scientist Salary   (based on 12 salaries)
# 8                UnitedHealth\nData Scientist Salary   (based on 91 salaries)
# 9                  Ford Motor\nData Scientist Salary   (based on 21 salaries)
#
#   avg salary min salary max salary                                  experience
# ...
